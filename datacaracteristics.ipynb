# %%
import pandas as pd
col_names = ["img", "train", "label","img_path"]
data = pd.read_csv('dataset_trainmodif.csv',names = col_names)

# %%
data = data.drop_duplicates('img')
data.groupby('label').count()
# Out:
#         img  train  img_path
# label
# 0      7921   7921      7921
# 1      7802   7802      7802
# 2      7583   7583      7583
# 3      7300   7300      7300
# 4      7516   7516      7516
# 5      6813   6813      6813
# 6      6574   6574      6574
# 7      5517   5517      5517
# 8      3087   3087      3087
# 9      1833   1833      1833
# 10     1651   1651      1651
# 11     7479   7479      7479
# 12     5881   5881      5881
# 13     6403   6403      6403
# 14     4978   4978      4978

# %%
# Out:
# {'train': 104293, 'valid': 10526}
# Epoch 0/7
# ----------
# torch.Size([64, 256, 256])
# tensor(3.2167, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.2274, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.2193, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.2437, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.1823, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.2394, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.2390, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.1505, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.1393, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# tensor(3.1776, device='cuda:0', grad_fn=<NllLossBackward>)
# torch.Size([64, 256, 256])
# ...
